# %% [markdown]
# # LangGraph Practice
#
# Welcome to your LangGraph practice notebook. This is where you'll build and test your graphs.

# %%
import os
from dotenv import load_dotenv
from utils.helpers import pretty_print_messages

# Load environment variables
load_dotenv()

print("Environment loaded.")

# %%
# Start coding your graph here
